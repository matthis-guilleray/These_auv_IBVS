# %%
import baseClass as bC
bC.BaseRos2.node_run(frequency=32)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import baseClass as bC
# ----> 2 bC.BaseRos2.node_run(frequency=32)
#
# File ~/workspace/IBVS_ROV/IBVS_ROV/baseClass.py:39, in BaseRos2.node_run(cls, **kwargs)
#      36 @classmethod
#      37 def node_run(cls, **kwargs):
#      38     obj = cls(**kwargs)
# ---> 39     with obj as e:
#      40         while(True):
#      41             print('Hello')
#
# AttributeError: __enter__

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 bC.BaseRos2.node_run(frequency=32)
#
# File ~/workspace/IBVS_ROV/IBVS_ROV/baseClass.py:38, in BaseRos2.node_run(cls, **kwargs)
#      36 @classmethod
#      37 def node_run(cls, **kwargs):
# ---> 38     obj = cls(*kwargs)
#      39     with obj as e:
#      40         while(True):
#
# File ~/workspace/IBVS_ROV/IBVS_ROV/baseClass.py:20, in BaseRos2.__init__(self, frequency)
#      18 def __init__(self, frequency=30):
# ---> 20     dT = 1/frequency
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
