# %%
import Tracking.common.utilsController as uCont
from scipy.spatial.transform import Rotation as R

# %%
rot = R.from_euler("yxz", [90, 90, 0], True).as_matrix()
trsl = [2, 0, 0]
cmd = [0, 0, 0, 1, 0, 0]

# %%
matrix_sk = uCont.construct_matrix_skew(trsl)
matrix_adjoint = uCont.contruct_matrix_adjoint(rot, matrix_sk)

# %%
matrix_adjoint @ cmd
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  2.22044605e-16,
#         1.00000000e+00, -2.22044605e-16])
